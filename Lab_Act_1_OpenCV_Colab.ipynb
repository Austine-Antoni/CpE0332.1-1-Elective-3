# %% [markdown]
# <a href="https://colab.research.google.com/github/Austine-Antoni/CpE0332.1-1-Elective-3/blob/main/Lab_Act_1_OpenCV_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Group 1
#
# ANTONI, ATENCIA, BAUYON, JAO, LEONARDO

# %% [markdown]
# Acquire an image

# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow

#Acquire the image
img = cv2.imread('/content/drive/MyDrive/Elec Lab/flower.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=273x274>
# <PIL.Image.Image image mode=RGB size=273x274>
# <PIL.Image.Image image mode=RGB size=273x274>

# %% [markdown]
# Rotate an image by 30 degrees

# %%
#Rotate the image by 30 degrees
#Get image dimensions
(h, w) = img.shape[:2]
(centerX, centerY) = (w // 2, h // 2)

#Define the rotation matrix
angle = 30  #angle in degrees
scale = 1.0  #scale factor
rotation_matrix = cv2.getRotationMatrix2D((centerX, centerY), angle, scale)

#This function rotates the image by 30 degrees
rotated_image = cv2.warpAffine(img, rotation_matrix, (w, h))

# %% [markdown]
# Flip an image horizontally

# %%
#Flip the image horizontally
flipped_img = cv2.flip(rotated_image, 1)

# %% [markdown]
# Display images

# %%
#Display images
cv2_imshow(img)
cv2_imshow(rotated_image)
cv2_imshow(flipped_img)
# Out:
# <PIL.Image.Image image mode=RGB size=273x274>
# <PIL.Image.Image image mode=RGB size=273x274>
# <PIL.Image.Image image mode=RGB size=273x274>
